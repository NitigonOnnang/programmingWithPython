# %% [markdown]
# # ตัวอย่างการใช้งาน google colab

# %% [markdown]
# ## เตรียมตัวก่อนเริ่ม
#
# ในการทำตัวอย่างนี้เราต้องใช้โหมด GPU ทำได้โดยใช้คำสั่ง `nvidia-smi` หรือหากใช้คำสั่งแล้วมีปัญหาให้ไปที่ `Edit` -> `Notebook settings` -> `Hardware accelerator`, เลือกเป็น `GPU`, จากนั้นกด `Save`.

# %%
# !nvidia-smi

# %% [markdown]
# **หมายเหตุ:** เพื่อให้ง่ายต่อการเข้าถึงไฟล์ในลำดับต่อไปให้สร้างตัวแปรชื่อ `HOME`สำหรับเก็บตำแหน่งไฟล์

# %%
import os
HOME = os.getcwd()
print(HOME)

# %% [markdown]
# ## Clone และ Install

# %% [markdown]
# **หมายเหตุ:** ในขั้นตอนนี้อาจจะใช้เวลาในการโหลดและติดตั้งขึ้นอยู่กับความเร็วของอินเตอร์เน็ตด้วย

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q

# %% [markdown]
# **หมายเหตุ:** ในการติดตั้งแพคเกจ [`roboflow`](https://pypi.org/project/roboflow) เราจำเป็นโหลดข้อมูลจาก [Roboflow Universe](https://universe.roboflow.com/).

# %%
# !pip install -q roboflow

# %% [markdown]
# ## Download model weights

# %% [markdown]
# **หมายเหตุ:** ในเอกสารของ YOLOv9 แนะนำให้ใช้รุ่น `yolov9-s` และ `yolov9-m` แต่ค่าน้ำหนักสำหรับโมเดลไม่มีให้เราต้องโหลดเพิ่มเติมจาก [repository](https://github.com/WongKinYiu/yolov9).

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !ls -la {HOME}/weights

# %% [markdown]
# ## โหลดข้อมูลตัวอย่าง

# %% [markdown]
# **หมายเหตุ:** หากต้องการใช้ไฟล์ของเราเอง ให้ทำการอัพโหลดไฟมายัง Google Colab และแก้ไข `SOURCE_IMAGE_PATH` ให้เป็นตำแหน่งของไฟล์ที่ได้อัพโหลด

# %%
# !wget -P {HOME}/data -q https://media.roboflow.com/notebooks/examples/dog.jpeg

# %%
SOURCE_IMAGE_PATH = f"/content/data/dog.jpeg"

# %% [markdown]
# ## ตรงจจัดด้วยโมเดล COCO

# %% [markdown]
# ### gelan-c

# %%
# !python detect.py --weights {HOME}/weights/gelan-c.pt --conf 0.1 --source {HOME}/data/dog.jpeg --device 0

# %% [markdown]
# **หมายเหตุ:** โดยปกติผลของการประมวลผลจะถูกเก็บไว้ที่ `{HOME}/yolov9/runs/detect/`, ในไดเรกทรอรี่ที่ชื่อ `exp`, `exp2`, `exp3`, ... สามารถแก้ไขได้ด้วยการใช้พารามิเตอร์ที่ชื่อ `--name`

# %% [markdown]
# แสดงผลลัพธ์ที่ได้

# %% [markdown]
# ## yolov9-e

# %%
# !python detect.py --weights {HOME}/weights/yolov9-e.pt --conf 0.1 --source /content/data/dog.jpeg --device 0

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/detect/exp4/dog.jpeg", width=600)

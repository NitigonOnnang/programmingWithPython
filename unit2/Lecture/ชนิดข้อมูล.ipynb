# %% [markdown]
# # **ชนิดข้อมูล**
# <img src='https://drive.google.com/uc?id=1RIMEocyM0uS6RN773JO_mgWb4NX5g325'>

# %% [markdown]
# ---
#
# # **จำนวนเต็ม int**
#
#
#
# > ข้อมูลที่เป็นตัวเลขที่ไม่มีจุดทศนิยม
#
# เช่น
#
# ```python
#  1
# 300
# 32549
# ```
#
# *จำนวนเต็มในบางภาษาอาจมีจำนวนหลักได้จำกัด แต่ว่าในภาษาไพธอนสามารถมีจำนวนหลักได้ไม่จำกัด ขึ้นกับหน่วยความจำของเครื่อง*

# %% [markdown]
# # **จำนวนจริง float**
#
#
# ---
#
#
# > ข้อมูลที่เป็นตัวเลขที่ประกอบด้วยจุดทศนิยม
#
#
# ```python
# 129.3
# 6.61
# ```
# ต่อให้ตัวเลขหลังจุดทศนิยมเป็น 0 ซึ่งในทางคณิตศาสตร์แล้วถือเป็นจำนวนเต็ม แต่หากเขียนจุดทศนิยมไปด้วยก็ถือเป็นข้อมูลชนิดจำนวนจริง เช่น
# ```python
#  111.00000
# ```
# จำนวนจริงในที่นี้เป็นจำนวนที่อยู่ในรูปทศนิยมแบบจุดลอย (floating point) หรือมักเรียกว่า float ซึ่งหมายถึงเลขทศนิยมที่อยู่ในรูปของจำนวนจริงตั้งแต่ 0 ถึงไม่เกิน 10 คูณด้วย 10 ยกกำลังเท่าไหร่ๆ เช่น
# $ 3.11×10^8 $ หรือ $1.293×10^2$
#
#
# ข้อมูลชนิดนี้ปกติแล้วจะถูกเก็บในรูปของจำนวนที่ใช้ e เช่น
# ```python
# 3.11e-8 # เท่ากับ 0.0000000311
# 1.293e2 # เท่ากับ 129.3
# ```

# %% [markdown]
# ---
# # **จำนวนเชิงซ้อน complex**
#
#
# > ข้อมูลที่ประกอบด้วย`ส่วนจริง`และ`ส่วนจินตภาพ` โดยส่วนจินตภาพจะเขียนโดยต่อท้ายด้วย `j`
#
# เช่น
# ```python
# 1+2j
# 5.32j
# ```
# ต่อให้ตัวเลขนำหน้า j เป็น 0 ซึ่งหมายถึงส่วนจินตภาพเป็น 0 แต่ถ้ามีการเขียน 0j อยู่ก็ยังถือเป็นจำนวนเชิงซ้อน
#
# ```python
# 1+0j
# ```

# %% [markdown]
# ---
#
#
# # **บูล bool**
#
#
#
# > ข้อมูลที่มีค่าเป็นเพียง ๒ แบบ คือจริงกับเท็จเท่านั้น
# ```python
# True
# False
# ```
# **🚦** โดยให้ระวังว่าจำเป็นต้อง`ขึ้นต้นด้วยตัวพิมพ์ใหญ่`เท่านั้น

# %% [markdown]
# ---
# # **สายอักขระ str**
#
#
# > ข้อมูลที่เป็นตัวอักษรหลายๆตัวมาต่อเรียงกัน ซึ่งต้อง`คร่อมด้วยเครื่องหมายคำพูด โดยจะใช้ขีดเดี่ยว ' หรือขีดคู่ "` ก็ได้
#
#
# ```python
# 'คนที่เขียนโปรแกรมได้คือคนที่เขียนโปรแกรม!!'
# "111111111111111111111111111111"
# '๑๒๙.๓'
# ```

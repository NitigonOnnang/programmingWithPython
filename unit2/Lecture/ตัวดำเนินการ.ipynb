# %% [markdown]
# ตัวดำเนินการ(Operator) จะเอาไว้กระทำบางอย่างกับข้อมูล เพื่อให้ได้คำตอบ ส่วนข้อมูลที่ถูกกระทำเรียกว่า Operand
# <img src='https://drive.google.com/uc?id=1Roxpt_7GIzIHyDPHw0ire6xJUND3o3Db'>

# %% [markdown]
# # <font color='DarkBlue'>**ตัวดำเนินการทางคณิตศาสตร์**</font>
#
# <img src='https://techvidvan.com/tutorials/wp-content/uploads/sites/2/2019/12/python-arithmetic-operators-1.jpg'>

# %%
x=25
y=6

# %%
#Addition(+)
print(x+y)

# %%
#Subtraction(-)
print(x-y)

# %%
#Multiplication(*)
print(x*y)

# %%
#Division(/)
print(x/y)

# %%
#Floor division(//)
print(x//y)

# %%
#Modulus(%)
print(x%y)

# %%
#Exponentiation(**)
print(x**y)

# %% [markdown]
# # <font color='DarkBlue'>**ลำดับความสำคัญทางคณิตศาสตร์**</font>
#
# <img src='https://cdn.shopify.com/s/files/1/1708/7117/products/order-of-operations-pemdas-classroom-poster-math-sproutbrite-757234_1024x1024.jpg?v=1646787847'>

# %%
5 - 5 + 10

# %%
7 * 4 / 2

# %%
4**3**2

# %%
5 - 5 / 3 + 2 ** 4 * 10

# %%
#จงหาผลลัพธ์ของนิพจน์(Expression)
2 + 8//3 * 2**2 + 6 * 5 - 13%5

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1NP8kl6MJEW8nMBQJ0CMS7q-GFMn63Pn1'>

# %% [markdown]
# # <font color='DarkBlue'>**นิพจน์(Expression)**</font>
#
# นิพจน์ (Expression) คือ การนำตัวแปรและตัวเลขมาเชื่อมด้วยเครื่องหมายคณิตศาสตร์ เช่น <font color='red'>a+b**2 </font>

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1NPTateeTtUjPoQ1QxlXCZoCPZhp64u-l'>

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1NPdFkf5d74zNYcJsCM-40HL7gF_fQKvq'>

# %% [markdown]
# # <font color='DarkBlue'>**ชนิดของข้อมูลตัวเลขที่คำนวณได้**</font>
#
# โดยปกตินำข้อมูลชนิดไหนมาคำนวณผลที่ออกมาก็จะได้เป็นชนิดนั้น เช่นจำนวนเต็มบวกจำนวนเต็มได้จำนวนเต็ม
#
# แต่ในไพธอน 3 ข้อมูลที่เป็นจำนวนเต็มหารจำนวนเต็มจะได้เป็นจำนวนจริง ซึ่งมีทศนิยมได้ ที่ต้องแปลงชนิดข้อมูลก็เพื่อให้เก็บค่าทศนิยมที่เกิดขึ้นจากการหารได้ นั่นเอง เช่น

# %%
print(3/7)  # int/int
type(3/7)   # ได้ float

# %% [markdown]
# ข้อมูลที่เป็นต่างชนิดกันก็สามารถนำมาคำนวณได้ เพียงแต่ผลลัพธ์ที่ได้นั้นจะกลายเป็นข้อมูลชนิดใดชนิดหนึ่งเท่านั้น
#
# โดยทั่วไปหากเก็บ<font color='firebrick'>**จำนวนเต็มกับจำนวนจริงมากระทำกันผลที่ได้จะออกมาเป็นจำนวนจริง**</font> เช่น

# %%
# float + int
print(type(1930.389 + 348))
print(type(3.3e-9 + 1))

# %% [markdown]
# ถ้า<font color='firebrick'>**จำนวนจริงหรือจำนวนเต็มทำกับจำนวนเชิงซ้อนก็จะได้จำนวนเชิงซ้อน**</font>

# %%
print((123+44j)/20)
type((123+44j)/20)

# %% [markdown]
# ข้อมูลชนิดบูลก็สามารถนำมาคำนวณกับตัวเลขได้ โดย True แทนค่า 1 และ False แทนค่า 0

# %%
True - True

# %%
False*100

# %%
True + 1.5

# %% [markdown]
# # <font color='navy'>**การคำนวณกับสายอักขระ**</font>
#
# ไม่เพียงแต่ตัวเลขจะมีการคำนวณเท่านั้น สายอักขระเองก็สามารถมีการคำนวณได้เช่นกัน แต่ความหมายในการคำนวณของสายอักขระนั้นจะต่างกันออกไปจากการคำนวณตัวเลขสักหน่อย โดยทำได้ค่อนข้างจำกัด
#
# โดยการนำสายอักขระมาบวกกันจะเป็นการนำ สายอักขระมาต่อกัน และการนำสายอักขระมาคูณจำนวนเต็มก็จะเป็นการคัดลอกสายอักขระตามจำนวนเท่ากับที่คูณ

# %%
'ฮ่า'*7

# %%
'ฮ่า'+'ๆ'*30

# %% [markdown]
# แต่ถ้านำสายอักขระมาคูณด้วยจำนวนจริงก็จะขัดข้อง หรือหากนำสายอักขระมาคูณหรือลบหรือหารกันเองก็ขัดข้องเช่นกัน

# %%
'ฮ่าๆ'*3.3

# %%
'ฮ่าๆๆ'-'ๆ'

# %% [markdown]
# ดังนั้น<font color='firebrick'>สายอักขระจึงทำได้แค่บวกกันเองหรือคูณกับจำนวนเต็มเท่านั้น</font>
#
# ระวังว่าสายอักขระที่เป็นตัวเลขหากนำมาบวกกันก็จะเป็นการเขียนตัวเลขต่อกัน ไม่ใช่การบวกตัวเลข

# %%
'555'+'555'

# %% [markdown]
# #<font color='navy'> **ฟังก์ชันเบื้องต้น**</font>
#
# <img src='https://drive.google.com/uc?id=1RtQRi-yqJgnJi9YHhwaBf75-vZUBVvNF'>

# %% [markdown]
# <img src='https://files.realpython.com/media/Basic-Input-Output-and-String-Formatting-in-Python_Watermarked.65ba5b535841.jpg'>

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1Rs6qmOBdXrDyDk0qV90JQ1Qjrr_mtlhf'>

# %%
c = 2.222
d = str(c)
print(d)
print(c)

# %% [markdown]
# # <font color='navy'>**อาร์กิวเมนต์หลายตัว**</font>
#
# อาร์กิวเมนต์ไม่จำเป็นที่จะต้องมีแค่ตัวเดียว อาจมีหลายตัวก็ได้ หากมีหลายตัวก็ต้อง<font color='firebrick'>**คั่นด้วยเครื่องหมายจุลภาค ,**</font> เช่น

# %%
print('a =', 1, ', b =', 2)

# %% [markdown]
# # <font color='navy'>**คีย์เวิร์ดของฟังก์ชัน**</font>
#
# นอกจากอาร์กิวเมนต์แล้ว ฟังก์ชันยังอาจประกอบด้วยสิ่งที่เรียกว่าคีย์เวิร์ด (keyword) ซึ่งเป็นอีกสิ่งหนึ่งที่สามารถป้อนให้กับฟังก์ชันได้ แต่ต่างจากอาร์กิวเมนต์ตรงที่ว่าการป้อนคีย์เวิร์ดจะต้องใส่ชื่อของ คีย์เวิร์ดนั้น
#
# ยกตัวอย่างการใช้คีย์เวิร์ดในฟังก์ชัน print

# %%
print('ฉันมีความสุข','555','๕๕๕','อยากหัวเราะดังๆ',sep='(^_^)')

# %% [markdown]
# ความหมายของ sep ในฟังก์ชัน print ก็คือคำที่ใช้แยกระหว่างอาร์กิวเมนต์แต่ละตัวที่ใส่ลงไป ดังนั้นจึงจะเห็นได้ว่ามี (^_^) ปรากฏขึ้นมาแทรก
#
# โดยปกติแล้วถ้าหาก ไม่พิมพ์ sep ลงไปฟังก์ชันก็ยังทำงานได้ปกติ เพียงแต่ตัวคั่นระหว่างแต่ละอาร์กิวเมนต์จะกลายเป็นการเว้นวรรค ดังที่เห็นในตัวอย่างที่แล้ว การเพิ่มคีย์เวิร์ดเข้ามาจึงเป็นแค่การแต่งเสริมเพิ่มเติม
#
# นอกจาก sep แล้วก็ยังมีคีย์เวิร์ดสำคัญอีกตัวคือ end ซึ่งเป็นตัวกำหนดการสิ้นสุดประโยค

# %%
print('การฝึกฝนที่ไม่มีความเจ็บปวดมันไม่มีความหมาย',end=' ')
print('เพราะคนเราไม่สามารถได้อะไรมาโดยที่ไม่ต้องเสียสละอะไร',end=' ')
print('แต่ว่าเมื่อทนความเจ็บปวดนั้นและก้าวผ่านมันไปได้',end='')
print('ถึงตอนนั้นคนเราก็จะมีจิตใจที่แกร่งกล้าไม่แพ้ใครๆ',end='!')

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1STTp66MhlzczT0XQZspDRE2h1IhGgBDQ'>

# %% [markdown]
# สิ่งที่ตรงข้ามกับการส่งออกข้อมูลก็คือการป้อนเข้า (input)
#
# ในภาษาไพธอนฟังก์ชันที่ใช้ในการป้อนเข้าข้อมูลชื่อฟังก์ชัน input

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1STolXyIGzVay_yWWdvf9m3ZLeIN8LN6C'>
#
# เมื่อ  prompt คือ ข้อความที่แสดงให้รู้ว่าจะให้ป้อนอะไร

# %%
a = input()
print('a คือ',a)

# %% [markdown]
# ในตัวอย่างข้างต้นจะเห็นว่าในวงเล็บหลัง input นั้นว่างเปล่า ไม่ได้ใส่อะไรลงไป แต่ที่จริงแล้วฟังก์ชัน input เองก็สามารถใส่อาร์กิวเมนต์ลงไปได้ ซึ่งพอใส่ลงไปแล้ว สิ่งนั้นจะกลายเป็น ข้อความที่เราต้องการให้แสดงผลออกมาก่อนที่จะให้ป้อนข้อความ
#
# โดยทั่วไปเหมือนเป็นข้อความที่ใช้บอกให้ผู้ใช้รู้ว่าจะต้องป้อนอะไร ขอยกตัวอย่างการใช้ เช่น

# %%
a = input('จงป้อนค่าอะไรสักอย่าง: ')
print('ข้อความที่ป้อนคือ ',a)

# %% [markdown]
# **สิ่งที่ต้องเน้นอีกอย่างคือ** <font color='firebrick'>ข้อมูลที่ป้อนเข้าไปด้วยฟังก์ชัน input นี้จะเป็นสายอักขระ หากต้องการจะได้ค่าเป็นจำนวนจริงหรือจำนวนเต็มก็จะต้องแปลงอีกที</font> เช่น

# %%
print("##########################################")
print("# โปรแกรมคำนวณหาค่าความต้านทานรวมแบบอนุกรม #")
print("#              RT = R1 + R2              #")
print("##########################################")
a = input('จงป้อนค่าตัวต้านทานตัวที่ 1[R1] :')
b = input('จงป้อนค่าตัวต้านทานตัวที่ 2[R2] :')
rt = a + b
print('ค่าความต้านทานรวมมีค่าเท่ากับ :',rt,' \u03A9')
# Out:
# ##########################################
# # โปรแกรมคำนวณหาค่าความต้านทานรวมแบบอนุกรม #
# #              RT = R1 + R2              #
# ##########################################
# จงป้อนค่าตัวต้านทานตัวที่ 1[R1] :5
# จงป้อนค่าตัวต้านทานตัวที่ 2[R2] :5
# ค่าความต้านทานรวมมีค่าเท่ากับ : 55  Ω

# %% [markdown]
# <img src='https://drive.google.com/uc?id=1SUG71vcyC8iORrjg_E5Yg6zyrq47qyH-'>
#
# # **ค่าที่ถูกส่งกลับมาในการเรียกใช้ฟังก์ชัน input() คือ <font color='firebrick'>string(str)</font>**

# %%
a = input('จงป้อนตัวเลขลงไป: ')
print(type(a))

# %%
a = float(input('จงป้อนตัวเลขลงไป: '))
print(type(a))

# %% [markdown]
# # <font color='navy'>**พิจารณาตัวอย่างต่อไปนี้**</font>

# %%
r = input("กรุณาป้อนรัศมี : ")
R = 2 * 3.1415 * r
print("เส้นรอบวงกลมที่มีรัศมี %f หน่วย มีความยาวเท่ากับ %f หน่วย"%( r, R ))

# %%
r = float(input("กรุณาป้อนรัศมี : "))
R = 2 * 3.1415 * r
print("เส้นรอบวงกลมที่มีรัศมี %f หน่วย มีความยาวเท่ากับ %f หน่วย"%( r, R ))

# %% [markdown]
# #จงเขียนโปรแกรมคำนวณพื้นที่สี่เหลี่ยมโดยรับค่าความกว้างและความสูงจากผู้ใช้และแสดงผลลัพธ์พื้นที่สี่เหลี่ยม

# %% [markdown]
# #จงเขียนโปรแกรมคำนวณพื้นที่สามเหลี่ยมโดยรับค่าความกว้างและความสูงจากผู้ใช้จากนั้นแสดงผลลัพธ์พื้นที่สามเหลี่ยม

# %% [markdown]
# #จงโปรแกรมคำนวณพื้นที่วงกลมโดยรับค่ารัศมีจากผู้ใช้จากนั้นแสดงผลลัพธ์พื้นที่วงกลม

# %% [markdown]
# #จงเขียนโปรแกรมคำนวณปริมาตรทรงกระบอกโดยรับค่ารัศมีและความสูงจากผู้ใช้ จากนั้นแสดงผลลัพธ์

# %% [markdown]
# # จงเขียนโปรแกรมคำนวณหาไฟฟ้าโดยรับจำนวนหน่วยที่ใช้ไปจากผู้ใช้ จากนั้นนำมาคำนวณ โดยกำหนดให้อัตราค่าไฟฟ้าหน่วยละ 4.5 บาท
